# %% [markdown]
# You are given the root of a binary search tree (BST) and an integer val.
#
# Find the node in the BST that the node's value equals val and return the subtree rooted with that node. If such a node does not exist, return null.
#
# Example 1:
#
# ![image.png](attachment:a54ee671-5091-4d0a-b33a-ed1d36800b37.png)
#
# Input: root = [4,2,7,1,3], val = 2
# Output: [2,1,3]
#
# Example 2:
#
# ![image.png](attachment:75bdfb9c-2752-4a73-9f8c-b9a59a3f82c7.png)
#
# Input: root = [4,2,7,1,3], val = 5
# Output: []
#
#
#
# Constraints:
#
#     The number of nodes in the tree is in the range [1, 5000].
#     1 <= Node.val <= 107
#     root is a binary search tree.
#     1 <= val <= 107

# %%
from typing import Optional

# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

        
class Solution:
    def searchBST(self, root: Optional[TreeNode], val: int) -> Optional[TreeNode]:
        if root is None:
            return None
        
        curr = root
        while val != curr.val:
    
            if val < curr.val:
                if curr.left:
                    curr = curr.left
                else:
                    return None
            elif val > curr.val:
                if curr.right:
                    curr = curr.right
                else:
                    return None
                
        return curr

# %%
s = Solution()
s.searchBST(TreeNode(4, TreeNode(2, TreeNode(1), TreeNode(3)), TreeNode(7)), 2)
