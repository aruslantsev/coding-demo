# %% [markdown]
# Given an m x n integer matrix matrix, if an element is 0, set its entire row and column to 0's.
#
# You must do it in place.
#
#
#
# Example 1:
#
# ![изображение.png](attachment:5a1a8e33-194a-427d-8125-0cdb5e368209.png)
#
# Input: matrix = [[1,1,1],[1,0,1],[1,1,1]]
# Output: [[1,0,1],[0,0,0],[1,0,1]]
#
# Example 2:
#
# ![изображение.png](attachment:32ad3f38-eb91-4350-bbda-d1fd50966117.png)
#
# Input: matrix = [[0,1,2,0],[3,4,5,2],[1,3,1,5]]
# Output: [[0,0,0,0],[0,4,5,0],[0,3,1,0]]
#
#
#
# Constraints:
#
#     m == matrix.length
#     n == matrix[0].length
#     1 <= m, n <= 200
#     -231 <= matrix[i][j] <= 231 - 1
#
#
#
# Follow up:
#
#     A straightforward solution using O(mn) space is probably a bad idea.
#     A simple improvement uses O(m + n) space, but still not the best solution.
#     Could you devise a constant space solution?

# %%
class Solution:
    def setZeroes(self, matrix: List[List[int]]) -> None:
        """
        Do not return anything, modify matrix in-place instead.
        """
        zero_cols = [False for _ in matrix[0]]
        zero_rows = [False for _ in matrix]
        
        for i, row in enumerate(matrix):
            for j, num in enumerate(row):
                if num == 0:
                    zero_rows[i] = True
                    zero_cols[j] = True
        for i, row in enumerate(zero_rows):
            if row:
                matrix[i] = [0 for _ in matrix[0]]
        for j, col in enumerate(zero_cols):
            if col:
                for i in range(len(matrix)):
                    matrix[i][j] = 0
        return

# %%
class Solution:
    def setZeroes(self, matrix: List[List[int]]) -> None:
        """
        Do not return anything, modify matrix in-place instead.
        """
        cols = set()
        for i, row in enumerate(matrix):
            zero_row = False
            for j, elem in enumerate(row):
                if elem == 0:
                    cols.add(j)
                    zero_row = True
            if zero_row:
                for j in range(len(row)):
                    matrix[i][j] = 0
        for col in cols:
            for i in range(len(matrix)):
                matrix[i][col] = 0
