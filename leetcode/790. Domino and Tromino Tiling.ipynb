# %% [markdown]
# You have two types of tiles: a 2 x 1 domino shape and a tromino shape. You may rotate these shapes.
#
# ![image.png](attachment:8fd7f9eb-86e2-4df5-be29-37ee6125166a.png)
#
# Given an integer n, return the number of ways to tile an 2 x n board. Since the answer may be very large, return it modulo 109 + 7.
#
# In a tiling, every square must be covered by a tile. Two tilings are different if and only if there are two 4-directionally adjacent cells on the board such that exactly one of the tilings has both squares occupied by a tile.
#
#
#
# Example 1:
#
# ![image.png](attachment:458f86f6-0ff9-4ea7-98e2-d59c9772d066.png)
#
# Input: n = 3
# Output: 5
# Explanation: The five different ways are show above.
#
# Example 2:
#
# Input: n = 1
# Output: 1
#
#
#
# Constraints:
#
#     1 <= n <= 1000

# %%
# Wrong?

class Solution:
    def numTilings(self, n: int) -> int:
        @cache
        def tiling(k):
            if k == 3:
                return 5
            if k == 2:
                return 2
            if k == 1:
                return 1
            return tiling(k - 1) + tiling(k - 2) + 2 * tiling(k - 3)
        return tiling(n)

# %%
class Solution:
    def numTilings(self, n: int) -> int:
        A = [0] * (n + 1)
        B = [1, 1] + [0] * (n - 1)
        for i in range(2, n + 1):
            A[i] = (B[i - 2] + A[i - 1]) % int(1e9 + 7)
            B[i] = (B[i - 1] + B[i - 2] + A[i - 1] * 2) % int(1e9 + 7)
        return B[n]
