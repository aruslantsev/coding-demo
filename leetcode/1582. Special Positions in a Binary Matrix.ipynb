# %% [markdown]
# Given an m x n binary matrix mat, return the number of special positions in mat.
#
# A position (i, j) is called special if mat[i][j] == 1 and all other elements in row i and column j are 0 (rows and columns are 0-indexed).
#
#
#
# Example 1:
#
# ![image.png](attachment:f913e5fc-524e-4b7c-b76d-7ab9ea4485e3.png)
#
# Input: mat = [[1,0,0],[0,0,1],[1,0,0]]
# Output: 1
# Explanation: (1, 2) is a special position because mat[1][2] == 1 and all other elements in row 1 and column 2 are 0.
#
# Example 2:
#
# ![image.png](attachment:52039736-d6e1-4796-aa3c-db2f4fb99c61.png)
#
# Input: mat = [[1,0,0],[0,1,0],[0,0,1]]
# Output: 3
# Explanation: (0, 0), (1, 1) and (2, 2) are special positions.
#
#
#
# Constraints:
#
#     m == mat.length
#     n == mat[i].length
#     1 <= m, n <= 100
#     mat[i][j] is either 0 or 1.

# %%
class Solution:
    def numSpecial(self, mat: List[List[int]]) -> int:
        row_sums = [sum(row) for row in mat]
        col_sums = [sum([row[i] for row in mat]) for i in range(len(mat[0]))]
        ans = 0
        for i, row in enumerate(mat):
            for j, num in enumerate(row):
                if row_sums[i] == col_sums[j] == num == 1:
                    ans += 1
        return ans
