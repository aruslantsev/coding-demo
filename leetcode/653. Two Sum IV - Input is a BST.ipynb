# %% [markdown]
# Given the root of a Binary Search Tree and a target number k, return true if there exist two elements in the BST such that their sum is equal to the given target.
#
#
#
# Example 1:
#
# ![изображение.png](attachment:89d1e4ba-2df1-4b49-8dfd-e45ab814e913.png)
#
# Input: root = [5,3,6,2,4,null,7], k = 9
# Output: true
#
# Example 2:
#
# ![изображение.png](attachment:7aa2696a-9f33-472f-8d02-65ba7e3d7384.png)
#
# Input: root = [5,3,6,2,4,null,7], k = 28
# Output: false

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def findTarget(self, root: Optional[TreeNode], k: int) -> bool:
        self.watched = set()
        self.found = False
        
        def dfs(node):
            if node is not None:
                if (k - node.val) in self.watched:
                    self.found = True
                self.watched.add(node.val)
                dfs(node.left)
                dfs(node.right)
                
        dfs(root)
        return self.found
