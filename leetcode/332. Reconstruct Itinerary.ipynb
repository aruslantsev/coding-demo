# %% [markdown]
# You are given a list of airline tickets where tickets[i] = [fromi, toi] represent the departure and the arrival airports of one flight. Reconstruct the itinerary in order and return it.
#
# All of the tickets belong to a man who departs from "JFK", thus, the itinerary must begin with "JFK". If there are multiple valid itineraries, you should return the itinerary that has the smallest lexical order when read as a single string.
#
#     For example, the itinerary ["JFK", "LGA"] has a smaller lexical order than ["JFK", "LGB"].
#
# You may assume all tickets form at least one valid itinerary. You must use all the tickets once and only once.
#
#
#
# Example 1:
#
# ![image.png](attachment:265be279-f742-4123-8aad-01ae02ed82ea.png)
#
# Input: tickets = [["MUC","LHR"],["JFK","MUC"],["SFO","SJC"],["LHR","SFO"]]
# Output: ["JFK","MUC","LHR","SFO","SJC"]
#
# Example 2:
#
# ![image.png](attachment:8c37b245-8645-4fe4-89a0-b412e83bc659.png)
#
# Input: tickets = [["JFK","SFO"],["JFK","ATL"],["SFO","ATL"],["ATL","JFK"],["ATL","SFO"]]
# Output: ["JFK","ATL","JFK","SFO","ATL","SFO"]
# Explanation: Another possible reconstruction is ["JFK","SFO","ATL","JFK","ATL","SFO"] but it is larger in lexical order.
#
#
#
# Constraints:
#
#     1 <= tickets.length <= 300
#     tickets[i].length == 2
#     fromi.length == 3
#     toi.length == 3
#     fromi and toi consist of uppercase English letters.
#     fromi != toi

# %%
from typing import List
from collections import defaultdict


class Solution:
    def findItinerary(self, tickets: List[List[str]]) -> List[str]:
        self.routes = defaultdict(list)
        for start, end in tickets:
            self.routes[start].append(end)
        for k, v in self.routes.items():
            self.routes[k] = sorted(v)

        self.ans = []
        self.finish = False

        def backtrack(curr):
            self.ans.append(curr)
            if all([len(v) == 0 for v in self.routes.values()]) or self.finish:
                self.finish = True
                return

            print(curr, self.routes[curr])
            for i, nxt in enumerate(self.routes[curr]):
                self.routes[curr].pop(i)
                backtrack(nxt)
                self.routes[curr].insert(i, nxt)
                if self.finish:
                    return
            if not self.finish:
                self.ans.pop()
                    
        backtrack("JFK")

        return self.ans

# %%
class Solution:
    def findItinerary(self, tickets: List[List[str]]) -> List[str]:
        graph = defaultdict(list)
        
        for src, dst in sorted(tickets, reverse=True):
            graph[src].append(dst)
            
        itinerary = []
        def dfs(airport):
            while graph[airport]:
                dfs(graph[airport].pop())
            itinerary.append(airport)
        
        dfs("JFK")
        
        return itinerary[::-1]
