# %% [markdown]
# Given a 2D grid of size m x n and an integer k. You need to shift the grid k times.
#
# In one shift operation:
#
#     Element at grid[i][j] moves to grid[i][j + 1].
#     Element at grid[i][n - 1] moves to grid[i + 1][0].
#     Element at grid[m - 1][n - 1] moves to grid[0][0].
#
# Return the 2D grid after applying shift operation k times.
#
# Example 1:
#
# ![изображение.png](attachment:7a0b7c88-e456-481f-a856-885daaa2f6d5.png)
#
# Input: grid = [[1,2,3],[4,5,6],[7,8,9]], k = 1
# Output: [[9,1,2],[3,4,5],[6,7,8]]
#
# Example 2:
#
# ![изображение.png](attachment:eadfd35b-b9ed-4e83-907a-8a2ab0ea1c99.png)
#
# Input: grid = [[3,8,1,9],[19,7,2,5],[4,6,11,10],[12,0,21,13]], k = 4
# Output: [[12,0,21,13],[3,8,1,9],[19,7,2,5],[4,6,11,10]]
#
# Example 3:
#
# Input: grid = [[1,2,3],[4,5,6],[7,8,9]], k = 9
# Output: [[1,2,3],[4,5,6],[7,8,9]]
#
#
#
# Constraints:
#
#     m == grid.length
#     n == grid[i].length
#     1 <= m <= 50
#     1 <= n <= 50
#     -1000 <= grid[i][j] <= 1000
#     0 <= k <= 100

# %%
from typing import List

class Solution:
    def shiftGrid(self, grid: List[List[int]], k: int) -> List[List[int]]:
        m = len(grid)
        n = len(grid[0])
        if k % (m * n) == 0:
            return grid
        
        row_shift = m - (k // n) % m
        k = k % n
        grid[:] = grid[row_shift:] + grid[:row_shift]
        
        if k > 0:
            for i in range(m):
                grid[i] = grid[i - 1][-k:] + grid[i]
                grid[i - 1] = grid[i - 1][:-k]
        
        return grid

# %%
s = Solution()
s.shiftGrid(grid=[[1,2,3],[4,5,6],[7,8,9]], k=1)
# Out:
# 3 1
# [[9, 1, 2], [3, 4, 5], [6, 7, 8]]

# %%
s.shiftGrid(grid=[[3,8,1,9],[19,7,2,5],[4,6,11,10],[12,0,21,13]], k=4)
# Out:
# 3 0
# [[12, 0, 21, 13], [3, 8, 1, 9], [19, 7, 2, 5], [4, 6, 11, 10]]

# %%
s.shiftGrid(grid=[[1,2,3],[4,5,6],[7,8,9]], k=9)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
s.shiftGrid([[1],[2],[3],[4],[7],[6],[5]], 23)
# Out:
# 5 0
# [[6], [5], [1], [2], [3], [4], [7]]
