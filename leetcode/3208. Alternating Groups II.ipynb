# %% [markdown]
# There is a circle of red and blue tiles. You are given an array of integers colors and an integer k. The color of tile i is represented by colors[i]:
#
#     colors[i] == 0 means that tile i is red.
#     colors[i] == 1 means that tile i is blue.
#
# An alternating group is every k contiguous tiles in the circle with alternating colors (each tile in the group except the first and last one has a different color from its left and right tiles).
#
# Return the number of alternating groups.
#
# Note that since colors represents a circle, the first and the last tiles are considered to be next to each other.
#
#
#
# Example 1:
#
# Input: colors = [0,1,0,1,0], k = 3
#
# Output: 3
#
# Explanation:
#
# ![image.png](attachment:cb12044a-2e21-4aa9-ac74-da267d41ec56.png)
#
# Alternating groups:
#
# ![image.png](attachment:f302e18c-f879-4794-a2aa-dc9673c05a27.png)
#
# ![image.png](attachment:98bae989-185d-4b08-9b69-27722d991966.png)
#
# ![image.png](attachment:f378ec05-7125-43b7-8fb3-ebd7845318ce.png)
#
# Example 2:
#
# Input: colors = [0,1,0,0,1,0,1], k = 6
#
# Output: 2
#
# Explanation:
#
# ![image.png](attachment:7a3d80e5-27ee-486a-b92a-5c5f43160e98.png)
#
# Alternating groups:
#
# ![image.png](attachment:53b42862-c413-495d-ae68-5aa008a0f2c3.png)
#
# ![image.png](attachment:46f0fa97-3e7f-4719-95f6-dad641b670a3.png)
#
# Example 3:
#
# Input: colors = [1,1,0,1], k = 4
#
# Output: 0
#
# Explanation:
#
# ![image.png](attachment:2414c122-507e-448a-9f25-a7038caa8436.png)
#
# Constraints:
#
#     3 <= colors.length <= 105
#     0 <= colors[i] <= 1
#     3 <= k <= colors.length

# %%
class Solution:
    def numberOfAlternatingGroups(self, colors: List[int], k: int) -> int:
        n = len(colors)
        start = None
        for i in range(1, n):
            if colors[i] == colors[i - 1]:
                start = i
                break
        if not start and colors[-1] != colors[0]:
            return n
        
        colors = colors[start:] + colors[:start]
        curr_window = 1
        ans = 0
        for i in range(1, n):
            if colors[i] == colors[i - 1]:
                if curr_window >= k:
                    ans += curr_window - k + 1
                curr_window = 1
            else:
                curr_window += 1
        if curr_window >= k:
            ans += curr_window - k + 1
        return ans

# %%
class Solution:
    def numberOfAlternatingGroups(self, colors: List[int], k: int) -> int:
        n = len(colors)
        start = None
        for i in range(1, n):
            if colors[i] == colors[i - 1]:
                start = i
                break
        if not start:
            if colors[-1] != colors[0]:
                return n
            start = 0

        curr_window = 1
        ans = 0
        for i in range(start + 1, start + n):
            if colors[i % n] == colors[(i - 1) % n]:
                if curr_window >= k:
                    ans += curr_window - k + 1
                curr_window = 1
            else:
                curr_window += 1
        if curr_window >= k:
            ans += curr_window - k + 1
        return ans
