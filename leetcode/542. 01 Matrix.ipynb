# %% [markdown]
# Given an m x n binary matrix mat, return the distance of the nearest 0 for each cell.
#
# The distance between two adjacent cells is 1.
#
#
#
# Example 1:
#
# ![image.png](attachment:02f731af-e84c-430f-afa4-0801b45a190a.png)
#
# Input: mat = [[0,0,0],[0,1,0],[0,0,0]]
# Output: [[0,0,0],[0,1,0],[0,0,0]]
#
# Example 2:
#
# ![image.png](attachment:85250fff-37a5-47a1-8fdb-b6ddfbcb3034.png)
#
# Input: mat = [[0,0,0],[0,1,0],[1,1,1]]
# Output: [[0,0,0],[0,1,0],[1,2,1]]
#
#
#
# Constraints:
#
#     m == mat.length
#     n == mat[i].length
#     1 <= m, n <= 104
#     1 <= m * n <= 104
#     mat[i][j] is either 0 or 1.
#     There is at least one 0 in mat.

# %%
class Solution:
    def updateMatrix(self, mat: List[List[int]]) -> List[List[int]]:
        if not mat:
            return []
        
        m = len(mat)
        n = len(mat[0])
        q = deque()
        for i in range(m):
            for j in range(n):
                if mat[i][j] == 0:
                    q.append([i, j])
                else:
                    mat[i][j] = float("inf")
        
        dxdy = [[0, 1], [0, -1], [1, 0], [-1, 0]]
        while q:
            x, y = q.popleft()
            for dx, dy in dxdy:
                xn, yn = x + dx, y + dy
                if 0 <= xn < m and 0 <= yn < n and mat[xn][yn] > mat[x][y] + 1:
                    q.append([xn, yn])
                    mat[xn][yn] = mat[x][y] + 1
        return mat
