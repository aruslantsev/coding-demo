# %% [markdown]
# You are given an m x n binary matrix grid.
#
# A move consists of choosing any row or column and toggling each value in that row or column (i.e., changing all 0's to 1's, and all 1's to 0's).
#
# Every row of the matrix is interpreted as a binary number, and the score of the matrix is the sum of these numbers.
#
# Return the highest possible score after making any number of moves (including zero moves).
#
#
#
# Example 1:
#
# ![image.png](attachment:5c302851-814b-4102-84a5-9b1589f49425.png)
#
# Input: grid = [[0,0,1,1],[1,0,1,0],[1,1,0,0]]
# Output: 39
# Explanation: 0b1111 + 0b1001 + 0b1111 = 15 + 9 + 15 = 39
#
# Example 2:
#
# Input: grid = [[0]]
# Output: 1
#
#
#
# Constraints:
#
#     m == grid.length
#     n == grid[i].length
#     1 <= m, n <= 20
#     grid[i][j] is either 0 or 1.

# %%
class Solution:
    def matrixScore(self, grid: List[List[int]]) -> int:
        for row in grid:
            if row[0] == 0:
                row[:] = [1 if num == 0 else 0 for num in row]
        
        for i in range(len(grid[0])):
            counts = Counter([row[i] for row in grid])
            if counts.get(0, 0) > counts.get(1, 0):
                for j in range(len(grid)):
                    grid[j][i] = 0 if grid[j][i] == 1 else 1

        ans = 0
        for row in grid:
            ans += int("0b" + "".join([str(i) for i in row]), 2)
        
        return ans
