# %% [markdown]
# There is an m x n grid with a ball. The ball is initially at the position [startRow, startColumn]. You are allowed to move the ball to one of the four adjacent cells in the grid (possibly out of the grid crossing the grid boundary). You can apply at most maxMove moves to the ball.
#
# Given the five integers m, n, maxMove, startRow, startColumn, return the number of paths to move the ball out of the grid boundary. Since the answer can be very large, return it modulo 109 + 7.
#
#
#
# Example 1:
#
# ![изображение.png](attachment:c536a76d-ab17-48b4-a09a-3eba1392a2c9.png)
#
# Input: m = 2, n = 2, maxMove = 2, startRow = 0, startColumn = 0
# Output: 6
#
# Example 2:
#
# ![изображение.png](attachment:bd1d3cb9-d3f4-47dd-af09-543ea3e8477c.png)
#
# Input: m = 1, n = 3, maxMove = 3, startRow = 0, startColumn = 1
# Output: 12
#
#
#
# Constraints:
#
#     1 <= m, n <= 50
#     0 <= maxMove <= 50
#     0 <= startRow < m
#     0 <= startColumn < n

# %%
class Solution:
    def findPaths(self, m: int, n: int, maxMove: int, startRow: int, startColumn: int) -> int:
        @cache
        def move(moves, row, col):
            if row >= m or row < 0 or col < 0 or col >= n:
                return 1
            if moves == 0:
                return 0
            
            return (
                move(moves - 1, row + 1, col) 
                + move(moves - 1, row, col + 1) 
                + move(moves - 1, row - 1, col) 
                + move(moves - 1, row, col - 1)
            )

        return move(maxMove, startRow, startColumn) % (10**9 + 7)
