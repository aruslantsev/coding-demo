# %% [markdown]
# Given the head of a sorted linked list, delete all duplicates such that each element appears only once. Return the linked list sorted as well.
#
#
#
# Example 1:
#
# ![изображение.png](attachment:77b7cb54-5429-481d-a2a5-5bfd5044fb7f.png)
#
# Input: head = [1,1,2]
# Output: [1,2]
#
# Example 2:
#
# ![изображение.png](attachment:3ada2b5e-07d5-4104-a949-c57f4267664c.png)
#
# Input: head = [1,1,2,3,3]
# Output: [1,2,3]
#
#
#
# Constraints:
#
#     The number of nodes in the list is in the range [0, 300].
#     -100 <= Node.val <= 100
#     The list is guaranteed to be sorted in ascending order.

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def deleteDuplicates(self, head: Optional[ListNode]) -> Optional[ListNode]:
        if head is None:
            return head
        head = ListNode(head.val, head)
        prev = head
        curr = head.next

        while curr is not None:
            while curr is not None and curr.val == prev.val:
                prev.next = curr.next
                curr = prev.next
            prev = curr
            if curr is not None:
                curr = curr.next
        return head
